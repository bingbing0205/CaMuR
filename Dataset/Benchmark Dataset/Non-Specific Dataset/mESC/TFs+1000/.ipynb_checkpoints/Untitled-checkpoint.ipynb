# %%
import pandas as pd

# %%
import numpy as np

# %%
Expression = pd.read_csv('BL--ExpressionData.csv', index_col=0, header=0)

# %%
Expression
# Out:
#           LPS_1h_S10  LPS_1h_S11  LPS_1h_S12  LPS_1h_S13  LPS_1h_S14  \
# SRSF1       0.704594    0.658504    0.065692    0.451760    0.329527
# DYNC1LI1    3.975294    0.007520    3.991525    0.019706    2.100333
# ALDOA       4.530484    4.154412    4.327416    4.653255    5.389968
# TAX1BP3     2.627902    3.882239    0.112526    2.953409    2.540965
# NEDD8       0.000000    2.164046    3.527270    2.931006    4.140375
# ...              ...         ...         ...         ...         ...
# POLR2D      2.285477    1.596213    0.000000    0.000000    1.392506
# SSR3        2.340326    1.595375    1.237964    1.801167    3.932543
# NACA        2.383671    3.625495    2.422970    3.557142    4.159349
# WBP11       0.366106    1.359480    0.704630    0.000000    0.297615
# PSMB1       3.822773    2.789293    1.857936    0.642684    2.932943
#
#           LPS_1h_S15  LPS_1h_S16  LPS_1h_S17  LPS_1h_S18  LPS_1h_S19  ...  \
# ...

# %%
SE_data = pd.read_csv('muti_data/DNA_bert_mousefeature.csv', index_col = 0, header = 0)

# %%
final_name = Expression.index.values

# %%
TF_500_SE = SE_data.loc[final_name]

# %%
TF_500_SE
# Out:
#              Dim_1     Dim_2     Dim_3     Dim_4     Dim_5     Dim_6  \
# gene
# SRSF1    -0.047991  0.754345 -0.175645 -0.583108  0.365919 -0.441354
# DYNC1LI1 -0.005271  0.934998  0.008647 -0.422456  0.276312 -0.475029
# ALDOA    -0.607992 -0.081559 -0.503831 -0.516919  0.145323 -0.575986
# TAX1BP3  -0.328768 -0.146656  0.059383 -0.747968  0.061259 -0.686514
# NEDD8    -0.309887 -0.042178 -0.260752 -0.094673  0.374733 -0.906362
# ...            ...       ...       ...       ...       ...       ...
# POLR2D   -0.483319  0.534926 -0.244507 -0.292626  0.221291 -0.681244
# SSR3     -0.176879  0.880928 -0.274813 -0.029253  0.223186 -0.718990
# NACA     -0.651958  0.619045 -0.258406 -0.398067  0.592687 -0.673459
# WBP11    -0.429608  0.310926  0.193618 -0.189635  0.144619 -0.691709
# PSMB1    -0.224407  1.031569 -0.277595 -0.447287  0.203704 -0.423057
#
#              Dim_7     Dim_8     Dim_9    Dim_10  ...   Dim_759   Dim_760  \
# gene                                              ...
# ...

# %%
TF_500_SE.to_csv('BL--DNASEData.csv')

# %%
SM_data = pd.read_csv('muti_data/mouse_promoter_embedding.csv', index_col = 0, header = 0)

# %%
SM_data
# Out:
#                   Dim_1     Dim_2     Dim_3     Dim_4     Dim_5     Dim_6  \
# gene
# 1110004F10RIK -0.034119  0.921757  0.296687 -0.630242  0.150109 -0.544550
# 1110038B12RIK -0.584614  0.180853 -0.115479 -0.367019  0.157972 -0.769619
# 1700006J14RIK -0.214793  0.897605  0.472437 -0.389981  0.192566 -1.050474
# 1700017B05RIK -0.390366  0.870548 -0.128067 -0.895575 -0.062762 -0.614078
# 1810009A15RIK -0.224076  0.725545 -0.314428 -0.844157  0.184550 -0.532299
# ...                 ...       ...       ...       ...       ...       ...
# USMG5          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# WARS           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# WHSC1L1        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ZFML           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ZNRD1          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                   Dim_7     Dim_8     Dim_9    Dim_10  ...   Dim_759  \
# ...

# %%
TF_500_SM = SM_data.loc[final_name]

# %%
TF_500_SM
# Out:
#              Dim_1     Dim_2     Dim_3     Dim_4     Dim_5     Dim_6  \
# gene
# SRSF1    -0.509770  0.513541  0.370665 -0.388576 -0.220941 -0.778181
# DYNC1LI1 -0.149582  0.889784 -0.093401 -0.464924  0.417269 -0.202248
# ALDOA    -0.040808  0.716872 -0.051100 -0.283766  0.620462 -0.885379
# TAX1BP3  -0.371869  0.384970  0.012752 -0.871327  0.132041 -0.566862
# NEDD8    -0.172892  0.622026 -0.249452 -0.494525  0.091388 -0.289746
# ...            ...       ...       ...       ...       ...       ...
# POLR2D   -0.564580  0.716562 -0.053795 -0.629942  0.361601 -0.721800
# SSR3     -0.110121  0.778055 -0.096608 -0.643463  0.392656 -0.406376
# NACA     -0.183851  0.715320 -0.009375 -0.791973  0.535452 -0.662315
# WBP11    -0.115709  0.325804 -0.127415 -0.331053  0.187849 -0.489472
# PSMB1    -0.421123  0.886710 -0.298374 -1.093338  0.062887 -0.659227
#
#              Dim_7     Dim_8     Dim_9    Dim_10  ...   Dim_759   Dim_760  \
# gene                                              ...
# ...

# %%
TF_500_SM.to_csv('BL--DNAPData.csv')

# %%
SM_data = pd.read_csv('muti_data/mouse_protein_embedding.csv', index_col = 0, header = 0)
TF_500_SM = SM_data.loc[final_name]
TF_500_SM.to_csv('BL--proteinData.csv')

# %%
SM_data = pd.read_csv('muti_data/mouse_text_embedding_feature.csv', index_col = 0, header = 0)
TF_500_SM = SM_data.loc[final_name]
TF_500_SM.to_csv('BL--SemData.csv')
