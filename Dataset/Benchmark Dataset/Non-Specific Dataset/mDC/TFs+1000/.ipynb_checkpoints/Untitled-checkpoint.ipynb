# %%
import pandas as pd
# Out:
# C:\anaconda3\envs\python39\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\anaconda3\envs\python39\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\anaconda3\envs\python39\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
import numpy as np

# %%
Expression = pd.read_csv('BL--ExpressionData.csv', index_col=0, header=0)

# %%
Expression
# Out:
#          LPS_1h_S10  LPS_1h_S11  LPS_1h_S12  LPS_1h_S13  LPS_1h_S14  \
# CNOT6L     0.028261    0.000000    0.000000    0.000000    0.000000
# OST4       3.691714    3.516806    3.853365    3.605028    4.342709
# XBP1       0.000000    0.983792    0.030061    3.212447    1.407312
# DYNLT1B    0.000000    0.000000    0.000000    1.212318    0.000000
# MBD2       1.056347    0.000000    0.007357    0.000000    1.072724
# ...             ...         ...         ...         ...         ...
# ALOX5AP    3.649206    3.085530    4.123222    3.956140    5.416169
# RPL15      2.576738    4.063016    2.741763    3.417909    4.348650
# RPL37      3.111160    4.257154    3.090640    2.853403    3.100042
# AIF1       0.000000    0.000000    0.000000    1.172886    0.028622
# TCEB3      0.604338    0.376301    0.000000    0.006576    0.525583
#
#          LPS_1h_S15  LPS_1h_S16  LPS_1h_S17  LPS_1h_S18  LPS_1h_S19  ...  \
# CNOT6L     0.019279    0.347554    0.686855    0.031136    0.000000  ...
# ...

# %%
SE_data = pd.read_csv('muti_data/new_mouse_sequeezefeature1.csv', index_col = 0, header = 0)

# %%
SE_data
# Out:
#                   Dim_1     Dim_2     Dim_3     Dim_4     Dim_5     Dim_6  \
# gene
# 0610009D07RIK  0.299242  0.102235  0.676012  0.039822  0.685692  0.275538
# 0610031J06RIK  0.475197  0.242331  0.780628  0.344310  0.508185  0.039403
# 1100001G20RIK  0.353609  0.207737  0.576459  0.047310  0.707724  0.270462
# 1110002B05RIK  0.451695  0.165203  0.678931  0.301122  0.487931  0.198876
# 1110004F10RIK  0.561846  0.288495  0.739345  0.415033  0.438627  0.127908
# ...                 ...       ...       ...       ...       ...       ...
# IGHV1-77       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# IGHV1-81       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# IGHV1-82       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# PLATR16        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ZFP989         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                   Dim_7     Dim_8     Dim_9    Dim_10  ...   Dim_759  \
# ...

# %%
final_name = Expression.index.values

# %%
TF_500_SE = SE_data.loc[final_name]

# %%
TF_500_SE
# Out:
#             Dim_1     Dim_2     Dim_3     Dim_4     Dim_5     Dim_6     Dim_7  \
# gene
# CNOT6L   1.390639 -0.717435  0.185057  0.441186  0.282048  0.487925 -0.783888
# OST4     0.310971  0.159924  0.600568  0.032764  0.694456  0.224188  0.396801
# XBP1     0.767772  0.154232  0.484091  0.339090  0.430886  0.337215 -0.132517
# DYNLT1B  0.305105  0.171584  0.683537  0.004280  0.727888  0.235936  0.335341
# MBD2     1.455383 -0.202801  0.640648  0.706460  0.235130  0.514185 -0.520862
# ...           ...       ...       ...       ...       ...       ...       ...
# ALOX5AP  0.284952  0.058097  0.600229 -0.029361  0.735262  0.175700  0.227897
# RPL15    0.595509  0.294881  0.495758  0.504193  0.468858  0.307869  0.198110
# RPL37    0.318349  0.068582  0.596064  0.050315  0.734798  0.246386  0.294434
# AIF1     0.326150  0.153607  0.626795  0.043551  0.765142  0.243245  0.373344
# TCEB3    1.466048 -0.183897  0.664033  0.698381  0.266544  0.598611 -0.485633
#
# ...

# %%
TF_500_SE.to_csv('BL-SequenceData.csv')

# %%
SM_data = pd.read_csv('muti_data/mouse_NLP_feature.csv', index_col = 0, header = 0)

# %%
SM_data
# Out:
#                   Dim_1     Dim_2     Dim_3     Dim_4     Dim_5     Dim_6  \
# gene
# 0610009D07RIK  0.471014  0.199348  0.038002  0.295562 -0.276268 -0.099807
# 0610031J06RIK  0.505860  0.134007  0.068729  0.264642 -0.276400 -0.091157
# 1100001G20RIK  0.577122  0.373861  0.090515  0.456118 -0.154784 -0.075040
# 1110002B05RIK  0.477488  0.003329  0.094551  0.653998 -0.457258  0.226939
# 1110004F10RIK  0.354065  0.069579  0.088155  0.582615 -0.442633  0.289511
# ...                 ...       ...       ...       ...       ...       ...
# ZSCAN21        0.460826 -0.092535 -0.088604  0.120868 -0.676295 -0.063761
# ZSWIM4         0.556745  0.264813  0.175675  0.149671 -0.561863 -0.254785
# ZWINT          0.355057 -0.064735 -0.339200 -0.107535 -0.424843  0.192493
# ZYX            0.274213 -0.139191  0.018842 -0.063306 -0.553494  0.114657
# ZZZ3           0.537616 -0.019052 -0.000089  0.139957 -0.455669 -0.028900
#
#                   Dim_7     Dim_8     Dim_9    Dim_10  ...   Dim_759  \
# ...

# %%
TF_500_SM = SM_data.loc[final_name]

# %%
TF_500_SM
# Out:
#             Dim_1     Dim_2     Dim_3     Dim_4     Dim_5     Dim_6     Dim_7  \
# gene
# CNOT6L   0.464549  0.020929 -0.130201 -0.071615 -0.569840 -0.264397  0.268942
# OST4     0.518341  0.074257  0.031099  0.013523 -0.486297 -0.047465  0.192646
# XBP1     0.550388  0.010819 -0.200580  0.108293 -0.495889 -0.037008  0.181287
# DYNLT1B  0.576096 -0.047247 -0.258734  0.130781 -0.396309 -0.179920  0.222497
# MBD2     0.673497  0.009434 -0.187878 -0.025704 -0.423407 -0.005659  0.338355
# ...           ...       ...       ...       ...       ...       ...       ...
# ALOX5AP  0.560406 -0.017727 -0.122378  0.094437 -0.636808  0.006783 -0.023835
# RPL15    0.619469 -0.223699 -0.041883 -0.033981 -0.547036 -0.036477  0.309218
# RPL37    0.609596 -0.199473 -0.083744 -0.012382 -0.670487 -0.112898  0.323193
# AIF1     0.605644 -0.153459 -0.138901  0.001858 -0.540280 -0.110284  0.264487
# TCEB3    0.710960  0.067883 -0.250175  0.023454 -0.382596 -0.068659  0.230751
#
# ...

# %%
TF_500_SM.to_csv('BL-SemanticsData.csv')
